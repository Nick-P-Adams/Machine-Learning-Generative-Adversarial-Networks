# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os
import gdown
import PIL
from zipfile import ZipFile
import pandas as pd
import tensorflow_datasets as tfds

# %%
# Approximately 20 mins
data,info=tfds.load('places365_small',with_info=True)
train_dataset=data['train']
# Out:
# Downloading and preparing dataset celeb_a_hq (?? GiB) to /home/nadams11/tensorflow_datasets/celeb_a_hq/256/0.1.0...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Approximately 20 mins
# ----> 2 data,info=tfds.load('celeb_a_hq/256',with_info=True)
#       3 train_dataset=data['train']
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/api_utils.py:52, in disallow_positional_args.<locals>.disallow_positional_args_dec(fn, instance, args, kwargs)
#      50 _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51 _check_required(fn, kwargs)
# ---> 52 return fn(*args, **kwargs)
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/registered.py:300, in load(name, split, data_dir, batch_size, in_memory, shuffle_files, download, as_supervised, decoders, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     298 if download:
#     299   download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 300   dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     302 if as_dataset_kwargs is None:
#     303   as_dataset_kwargs = {}
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/api_utils.py:52, in disallow_positional_args.<locals>.disallow_positional_args_dec(fn, instance, args, kwargs)
#      50 _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51 _check_required(fn, kwargs)
# ---> 52 return fn(*args, **kwargs)
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py:285, in DatasetBuilder.download_and_prepare(self, download_dir, download_config)
#     281 with file_format_adapter.incomplete_dir(self._data_dir) as tmp_data_dir:
#     282   # Temporarily assign _data_dir to tmp_data_dir to avoid having to forward
#     283   # it to every sub function.
#     284   with utils.temporary_assignment(self, "_data_dir", tmp_data_dir):
# --> 285     self._download_and_prepare(
#     286         dl_manager=dl_manager,
#     287         download_config=download_config)
#     289     # NOTE: If modifying the lines below to put additional information in
#     290     # DatasetInfo, you'll likely also want to update
#     291     # DatasetInfo.read_from_directory to possibly restore these attributes
#     292     # when reading from package data.
#     293
#     294     # Update the DatasetInfo metadata by computing statistics from the data.
#     295     if (download_config.compute_stats == download.ComputeStatsMode.SKIP or
#     296         download_config.compute_stats == download.ComputeStatsMode.AUTO and
#     297         bool(self.info.splits.total_num_examples)
#     298        ):
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py:946, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, download_config)
#     944 def _download_and_prepare(self, dl_manager, download_config):
#     945   # Extract max_examples_per_split and forward it to _prepare_split
# --> 946   super(GeneratorBasedBuilder, self)._download_and_prepare(
#     947       dl_manager=dl_manager,
#     948       max_examples_per_split=download_config.max_examples_per_split,
#     949   )
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py:804, in FileAdapterBuilder._download_and_prepare(self, dl_manager, **prepare_split_kwargs)
#     802 # Generating data for all splits
#     803 split_dict = splits_lib.SplitDict()
# --> 804 for split_generator in self._split_generators(dl_manager):
#     805   if splits_lib.Split.ALL == split_generator.split_info.name:
#     806     raise ValueError(
#     807         "tfds.Split.ALL is a special split keyword corresponding to the "
#     808         "union of all splits, so cannot be used as key in "
#     809         "._split_generator()."
#     810     )
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/image/celebahq.py:118, in CelebAHq._split_generators(self, dl_manager)
#     116 def _split_generators(self, dl_manager):
#     117   """Returns SplitGenerators."""
# --> 118   image_tar_file = os.path.join(dl_manager.manual_dir,
#     119                                 self.builder_config.file_name)
#     120   if not tf.io.gfile.exists(image_tar_file):
#     121     # The current celebahq generation code depends on a concrete version of
#     122     # pillow library and cannot be easily ported into tfds.
#     123     msg = "You must download the dataset files manually and place them in: "
#
# File /usr/local/share/anaconda3/envs/ewu-dmls/lib/python3.8/site-packages/tensorflow_datasets/core/download/download_manager.py:365, in DownloadManager.manual_dir(self)
#     363 """Returns the directory containing the manually extracted data."""
#     364 if not tf.io.gfile.exists(self._manual_dir):
# --> 365   raise AssertionError(
#     366       'Manual directory {} does not exist. Create it and download/extract '
#     367       'dataset artifacts in there.'.format(self._manual_dir))
#     368 return self._manual_dir
#
# AssertionError: Manual directory /home/nadams11/tensorflow_datasets/downloads/manual/celeb_a_hq does not exist. Create it and download/extract dataset artifacts in there.

# %%
# Get names of classes
class_names=[name for name in info.features['label'].names]
class_types=len(class_names)

# %%
for x in train_dataset.take(5):
  plt.imshow(x['image'])
  plt.show()
  print(class_names[x['label']])
# Out:
# 2022-05-24 12:10:09.308526: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-05-24 12:10:09.326093: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3600000000 Hz
# runway
# baseballdiamond
# forest
# mobilehomepark
# airplane

# %%
IMAGE_SIZE=256

@tf.function
def preprocess(data):
  image=data['image']
  image=tf.cast(image,tf.float32)/127.5-1
  image=tf.image.resize(image,(IMAGE_SIZE, IMAGE_SIZE))
  return image,data['label']

train_dataset=train_dataset.map(preprocess,num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function preprocess at 0x7f4a5876f310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function preprocess at 0x7f4a5876f310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function preprocess at 0x7f4a5876f310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
class ConditionBatchNormalization(tf.keras.Model):
  def __init__(self):
    super(ConditionBatchNormalization, self).__init__()
    self.decay = 0.9
    self.epsilon = 1e-05
    self.test_mean=tf.Variable(initial_value=0, trainable=False, dtype=tf.float32)
    self.test_var=tf.Variable(initial_value=1, trainable=False, dtype=tf.float32)

  def build(self, input_shape):
    self.num_channels=input_shape[0][-1]
    self.beta_mapping=tf.keras.layers.Dense(self.num_channels)
    self.gamma_mapping=tf.keras.layers.Dense(self.num_channels)
    
  def call(self, x, training=None):
    #Generate beta, gamma
    x, conditions = x
    beta = self.beta_mapping(conditions)
    gamma = self.gamma_mapping(conditions)

    beta = tf.reshape(beta, shape=[-1, 1, 1, self.num_channels])
    gamma = tf.reshape(gamma, shape=[-1, 1, 1, self.num_channels])
    if training:
        #Calculate mean and varience of X.
        batch_mean, batch_var = tf.nn.moments(x, [0, 1, 2])
        #Calculate parameters for test set 
        self.test_mean = self.test_mean * self.decay + batch_mean * (1 - self.decay)
        self.test_var = self.test_var * self.decay + batch_var * (1 - self.decay)

        return tf.nn.batch_normalization(x, batch_mean, batch_var, beta, gamma, self.epsilon)
    else:
        return tf.nn.batch_normalization(x, self.test_mean, self.test_var, beta, gamma, self.epsilon)

class SelfAttention(tf.keras.Model):
  def __init__(self):
    super(SelfAttention, self).__init__()

  def build(self, input_shape):
    self.num_channels=input_shape[-1]
    self.hw = input_shape[1]*input_shape[2]
    self.conv_f=tf.keras.layers.Conv2D(self.num_channels // 8, 1)
    self.conv_g=tf.keras.layers.Conv2D(self.num_channels // 8, 1)
    self.conv_h=tf.keras.layers.Conv2D(self.num_channels//2, 1)
    self.conv_o=tf.keras.layers.Conv2D(self.num_channels, 1)

  def call(self, x):
    bs = x.shape[0]
    f = self.conv_f(x)  # [bs, h, w, c']
    g = self.conv_g(x)  # [bs, h, w, c']
    h = self.conv_h(x)  # [bs, h, w, c]

    f=tf.keras.layers.Reshape([self.hw, f.shape[-1]])(f)
    g=tf.keras.layers.Reshape([self.hw, g.shape[-1]])(g)
    h=tf.keras.layers.Reshape([self.hw, h.shape[-1]])(h)
    # N = h * w
    s = tf.matmul(g, f, transpose_b=True)  # # [bs, N, N]
    beta = tf.nn.softmax(s)  # attention map

    o = tf.matmul(beta, h)  # [bs, N, C]
    o = tf.keras.layers.Reshape([x.shape[1], x.shape[2], self.num_channels//2])(o)
    o = self.conv_o(o)
      # [bs, h, w, C]
    return x + o

# %% [markdown]
# BIGGAN Architecture Implementations - BigGAN 128

# %%
#BigGAN 128 - G
latent_dim = 120
slice_latent_dim = 20
class_dims = 128
channels = 96

def residual_block_up(image_input, concat_input, channels):  

    block_a=tf.keras.layers.UpSampling2D()(image_input)
    block_a=tf.keras.layers.Conv2D(channels,1)(block_a)

    block_b=ConditionBatchNormalization()([image_input, concat_input])
    block_b=tf.keras.layers.ReLU()(block_b)
    block_b=tf.keras.layers.UpSampling2D()(block_b)
    
    block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
    block_b=ConditionBatchNormalization()([block_b, concat_input])
    block_b=tf.keras.layers.ReLU()(block_b)
    block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)

    final_output=tf.keras.layers.Add()([block_a,block_b])
    return final_output

def crop_noise(noise, idx):
    return noise[:, idx*slice_latent_dim : (idx+1)*slice_latent_dim]

noise=keras.Input(shape=(latent_dim,),name='noise')

input_classes=tf.keras.layers.Input(shape=(1,),name='class')
input_classes_embedding=tf.keras.layers.Embedding(class_types,class_dims)(input_classes)
input_classes_embedding=tf.keras.layers.Flatten()(input_classes_embedding)

noise_slice=tf.keras.layers.Lambda(lambda x:crop_noise(x, idx=0))(noise)
model=tf.keras.layers.concatenate([noise_slice,input_classes_embedding])
model=tf.keras.layers.Dense(4* 4* 16 * channels)(model)
model=tf.keras.layers.Reshape((4,4,16 * channels))(model)

non_local_block=[False, False, False,True,False]
channel_multipliers=[16, 8, 4, 2, 1]
for x in range(5):
    noise_slice=tf.keras.layers.Lambda(lambda x:crop_noise(x, idx=0))(noise)
    concat=tf.keras.layers.concatenate([noise_slice,input_classes_embedding])

    model=residual_block_up(model, concat, channels*channel_multipliers[x])
    if non_local_block[x]:
      model=SelfAttention()(model)

model=tf.keras.layers.BatchNormalization()(model)
model=tf.keras.layers.ReLU()(model)
model=tf.keras.layers.Conv2D(3,3,padding='same',activation='tanh')(model)

generator=tf.keras.models.Model([noise,input_classes],model)
generator.summary()
tf.keras.utils.plot_model(generator,show_shapes=True)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method SelfAttention.call of <__main__.SelfAttention object at 0x7f4a595d3520>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method SelfAttention.call of <__main__.SelfAttention object at 0x7f4a595d3520>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method SelfAttention.call of <__main__.SelfAttention object at 0x7f4a595d3520>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# class (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# noise (InputLayer)              [(None, 120)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 128)       2688        class[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 148)          0           lambda[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 24576)        3661824     concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4, 4, 1536)   0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 148)          0           lambda_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization ( (None, 4, 4, 1536)   457730      reshape[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 4, 4, 1536)   0           condition_batch_normalization[0][
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 1536)   0           re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 1536)   21235200    up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 8, 8, 1536)   457730      conv2d_1[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 1536)   0           reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 8, 8, 1536)   0           condition_batch_normalization_1[0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 8, 8, 1536)   2360832     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 1536)   21235200    re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 1536)   0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 148)          0           lambda_2[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_2 (None, 8, 8, 1536)   457730      add[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 8, 8, 1536)   0           condition_batch_normalization_2[0
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 1536) 0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 768)  10617600    up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_3 (None, 16, 16, 768)  228866      conv2d_4[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 1536) 0           add[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 16, 16, 768)  0           condition_batch_normalization_3[0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 768)  1180416     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 768)  5309184     re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 768)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 148)          0           lambda_3[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_4 (None, 16, 16, 768)  228866      add_1[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 16, 16, 768)  0           condition_batch_normalization_4[0
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 768)  0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 384)  2654592     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_5 (None, 32, 32, 384)  114434      conv2d_7[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 768)  0           add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 384)  0           condition_batch_normalization_5[0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 384)  295296      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 384)  1327488     re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 384)  0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 148)          0           lambda_4[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_6 (None, 32, 32, 384)  114434      add_2[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 32, 32, 384)  0           condition_batch_normalization_6[0
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 384)  0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 192)  663744      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_7 (None, 64, 64, 192)  57218       conv2d_10[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 384)  0           add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 64, 64, 192)  0           condition_batch_normalization_7[0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 192)  73920       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 192)  331968      re_lu_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 192)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# self_attention (SelfAttention)  (None, 64, 64, 192)  46416       add_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 148)          0           lambda_5[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_8 (None, 64, 64, 192)  57218       self_attention[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 64, 64, 192)  0           condition_batch_normalization_8[0
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 128, 128, 192 0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 96) 165984      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_9 (None, 128, 128, 96) 28610       conv2d_13[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 192 0           self_attention[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 128, 128, 96) 0           condition_batch_normalization_9[0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 96) 18528       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 96) 83040       re_lu_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 96) 0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 96) 384         add_4[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 128, 128, 96) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 3)  2595        re_lu_10[0][0]
# ==================================================================================================
# Total params: 73,469,735
# Trainable params: 73,469,523
# Non-trainable params: 212
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
#BigGAN 128 - D
def residual_block_down(input_image,channels,down=True):
  block_a=tf.keras.layers.Conv2D(channels,1)(input_image)
  if down:
    block_a=tf.keras.layers.AveragePooling2D()(block_a)

  block_b=tf.keras.layers.ReLU()(input_image)
  block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
  block_b=tf.keras.layers.ReLU()(block_b)
  block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
  if down:
    block_b=tf.keras.layers.AveragePooling2D()(block_b)

  final_output=tf.keras.layers.Add()([block_a,block_b])
  return final_output

input_image=tf.keras.layers.Input(shape=(256, 256, 3),name='image')

input_classes=tf.keras.layers.Input(shape=(1,),name='class')
input_classes_embedding=tf.keras.layers.Embedding(class_types,class_dims)(input_classes)
input_classes_embedding=tf.keras.layers.Flatten()(input_classes_embedding)

model=tf.keras.layers.Conv2D(channels,3,1,padding='same')(input_image)

non_local_block=[True,False,False,False,False]
down_list=[True,True,True,True,False]
channel_multipliers=[2,4,8,16,16]
for x in range(5):
  model=residual_block_down(model,channels=channels*channel_multipliers[x],down=down_list[x])
  if non_local_block[x]:
    model=SelfAttention()(model)
#Final residual block
model=tf.keras.layers.GlobalAveragePooling2D()(model)

model=tf.keras.layers.concatenate([input_classes_embedding,model])
model=tf.keras.layers.Dense(1)(model)

discriminator=tf.keras.models.Model([input_image, input_classes],model)
discriminator.summary()
tf.keras.utils.plot_model(discriminator,show_shapes=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 96) 2688        image[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 256, 256, 96) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 192 166080      re_lu_11[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 256, 256, 192 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 192 18624       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 192 331968      re_lu_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 128, 128, 192 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 128, 128, 192 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 192 0           average_pooling2d[0][0]
#                                                                  average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# self_attention_1 (SelfAttention (None, 128, 128, 192 46416       add_5[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 128, 128, 192 0           self_attention_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 384 663936      re_lu_13[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 128, 128, 384 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 384 74112       self_attention_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 384 1327488     re_lu_14[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 64, 64, 384)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 64, 64, 384)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 384)  0           average_pooling2d_2[0][0]
#                                                                  average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 64, 64, 384)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 768)  2654976     re_lu_15[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 64, 64, 768)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 768)  295680      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 768)  5309184     re_lu_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 32, 32, 768)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 32, 32, 768)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 768)  0           average_pooling2d_4[0][0]
#                                                                  average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 32, 32, 768)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 1536) 10618368    re_lu_17[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 32, 32, 1536) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 1536) 1181184     add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 1536) 21235200    re_lu_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 16, 16, 1536) 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 16, 16, 1536) 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 1536) 0           average_pooling2d_6[0][0]
#                                                                  average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 16, 16, 1536) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 1536) 21235200    re_lu_19[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 16, 16, 1536) 0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# class (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 1536) 2360832     add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 1536) 21235200    re_lu_20[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 128)       2688        class[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 1536) 0           conv2d_29[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           embedding_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1536)         0           add_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1664)         0           flatten_1[0][0]
#                                                                  global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1665        concatenate_6[0][0]
# ==================================================================================================
# Total params: 88,761,489
# Trainable params: 88,761,489
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# BIGGAN Architecture Implementations - BigGAN 256

# %%
#BigGAN 256 - G
latent_dim = 140
slice_latent_dim=20
class_dims = 128
channels = 96

def residual_block_up(image_input, concat_input, channels):  

    block_a=tf.keras.layers.UpSampling2D()(image_input)
    block_a=tf.keras.layers.Conv2D(channels,1)(block_a)

    block_b=ConditionBatchNormalization()([image_input, concat_input])
    block_b=tf.keras.layers.ReLU()(block_b)
    block_b=tf.keras.layers.UpSampling2D()(block_b)
    
    block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
    block_b=ConditionBatchNormalization()([block_b, concat_input])
    block_b=tf.keras.layers.ReLU()(block_b)
    block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)

    final_output=tf.keras.layers.Add()([block_a,block_b])
    return final_output

def crop_noise(noise, idx):
    return noise[:, idx*slice_latent_dim : (idx+1)*slice_latent_dim]

noise=keras.Input(shape=(latent_dim,),name='noise')

input_classes=tf.keras.layers.Input(shape=(1,),name='class')
input_classes_embedding=tf.keras.layers.Embedding(class_types,class_dims)(input_classes)
input_classes_embedding=tf.keras.layers.Flatten()(input_classes_embedding)

noise_slice=tf.keras.layers.Lambda(lambda x:crop_noise(x, idx=0))(noise)
model=tf.keras.layers.concatenate([noise_slice,input_classes_embedding])
model=tf.keras.layers.Dense(4* 4* 16 * channels)(model)
model=tf.keras.layers.Reshape((4,4,16*channels))(model)

non_local_block=[False, True, False,False,False,False,False]
channel_multipliers=[16, 16, 8, 8, 4, 2, 1]
for x in range(1, 7):
    noise_slice=tf.keras.layers.Lambda(lambda x:crop_noise(x, idx=0))(noise)
    concat=tf.keras.layers.concatenate([noise_slice,input_classes_embedding])

    model=residual_block_up(model, concat, channels*channel_multipliers[x])
    if non_local_block[x]:
      model=SelfAttention()(model)

model=tf.keras.layers.BatchNormalization()(model)
model=tf.keras.layers.ReLU()(model)
model=tf.keras.layers.Conv2D(3,3,padding='same',activation='tanh')(model)

generator=tf.keras.models.Model([noise,input_classes],model)
generator.summary()
tf.keras.utils.plot_model(generator,show_shapes=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# class (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# noise (InputLayer)              [(None, 140)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 128)       2688        class[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 128)          0           embedding_2[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 148)          0           lambda_6[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 24576)        3661824     concatenate_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 4, 4, 1536)   0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 148)          0           lambda_7[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 4, 4, 1536)   457730      reshape_1[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 4, 4, 1536)   0           condition_batch_normalization_10[
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 8, 8, 1536)   0           re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 1536)   21235200    up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 8, 8, 1536)   457730      conv2d_33[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 8, 8, 1536)   0           reshape_1[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 8, 8, 1536)   0           condition_batch_normalization_11[
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 1536)   2360832     up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 1536)   21235200    re_lu_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 1536)   0           conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# self_attention_2 (SelfAttention (None, 8, 8, 1536)   2951808     add_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 148)          0           lambda_8[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 8, 8, 1536)   457730      self_attention_2[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 8, 8, 1536)   0           condition_batch_normalization_12[
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 16, 16, 1536) 0           re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 768)  10617600    up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 16, 16, 768)  228866      conv2d_36[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 16, 16, 1536) 0           self_attention_2[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 16, 16, 768)  0           condition_batch_normalization_13[
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 768)  1180416     up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 768)  5309184     re_lu_24[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 768)  0           conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 148)          0           lambda_9[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 16, 16, 768)  228866      add_11[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 16, 16, 768)  0           condition_batch_normalization_14[
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 32, 32, 768)  0           re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 768)  5309184     up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 32, 32, 768)  228866      conv2d_39[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 32, 32, 768)  0           add_11[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 32, 32, 768)  0           condition_batch_normalization_15[
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 768)  590592      up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 768)  5309184     re_lu_26[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 768)  0           conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 148)          0           lambda_10[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 32, 32, 768)  228866      add_12[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 32, 32, 768)  0           condition_batch_normalization_16[
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 64, 64, 768)  0           re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 384)  2654592     up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 64, 64, 384)  114434      conv2d_42[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 64, 64, 768)  0           add_12[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 64, 64, 384)  0           condition_batch_normalization_17[
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 384)  295296      up_sampling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 384)  1327488     re_lu_28[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 384)  0           conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 148)          0           lambda_11[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 64, 64, 384)  114434      add_13[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 64, 64, 384)  0           condition_batch_normalization_18[
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 128, 128, 384 0           re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 192 663744      up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_1 (None, 128, 128, 192 57218       conv2d_45[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 128, 128, 384 0           add_13[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 128, 128, 192 0           condition_batch_normalization_19[
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 192 73920       up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 128, 128, 192 331968      re_lu_30[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 20)           0           noise[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 128, 128, 192 0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 148)          0           lambda_12[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_2 (None, 128, 128, 192 57218       add_14[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 128, 128, 192 0           condition_batch_normalization_20[
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 256, 256, 192 0           re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 96) 165984      up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# condition_batch_normalization_2 (None, 256, 256, 96) 28610       conv2d_48[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 256, 256, 192 0           add_14[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 256, 256, 96) 0           condition_batch_normalization_21[
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 96) 18528       up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 256, 256, 96) 83040       re_lu_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 256, 256, 96) 0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 96) 384         add_15[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 256, 256, 96) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 256, 256, 3)  2595        re_lu_33[0][0]
# ==================================================================================================
# Total params: 88,041,819
# Trainable params: 88,041,603
# Non-trainable params: 216
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
#BigGAN 256 - D
def residual_block_down(input_image,channels,down=True):
  block_a=tf.keras.layers.Conv2D(channels,1)(input_image)
  if down:
    block_a=tf.keras.layers.AveragePooling2D()(block_a)

  block_b=tf.keras.layers.ReLU()(input_image)
  block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
  block_b=tf.keras.layers.ReLU()(block_b)
  block_b=tf.keras.layers.Conv2D(channels,3,padding='same')(block_b)
  if down:
    block_b=tf.keras.layers.AveragePooling2D()(block_b)

  final_output=tf.keras.layers.Add()([block_a,block_b])
  return final_output

input_image=tf.keras.layers.Input(shape=(256, 256, 3),name='image')

input_classes=tf.keras.layers.Input(shape=(1,),name='class')
input_classes_embedding=tf.keras.layers.Embedding(class_types,class_dims)(input_classes)
input_classes_embedding=tf.keras.layers.Flatten()(input_classes_embedding)

model=tf.keras.layers.Conv2D(channels,3,1,padding='same')(input_image)

non_local_block=[False,False,False,True,False,False,False]
down_list=[True,True,True,True,True,True,False]
channel_multipliers=[2,4,8,8,16,16,16]
for x in range(7):
  model=residual_block_down(model,channels=channels*channel_multipliers[x],down=down_list[x])
  if non_local_block[x]:
    model=SelfAttention()(model)
#Final residual block
model=tf.keras.layers.GlobalAveragePooling2D()(model)

model=tf.keras.layers.concatenate([input_classes_embedding,model])
model=tf.keras.layers.Dense(1)(model)

discriminator=tf.keras.models.Model([input_image, input_classes],model)
discriminator.summary()
tf.keras.utils.plot_model(discriminator,show_shapes=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 96) 2688        image[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 256, 256, 96) 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 192 166080      re_lu_34[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 256, 256, 192 0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 192 18624       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 256, 256, 192 331968      re_lu_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 128, 128, 192 0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 128, 128, 192 0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 128, 128, 192 0           average_pooling2d_8[0][0]
#                                                                  average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 128, 128, 192 0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 384 663936      re_lu_36[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 128, 128, 384 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 384 74112       add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 384 1327488     re_lu_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 64, 64, 384)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 64, 64, 384)  0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 384)  0           average_pooling2d_10[0][0]
#                                                                  average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 64, 64, 384)  0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 768)  2654976     re_lu_38[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 64, 64, 768)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 768)  295680      add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 768)  5309184     re_lu_39[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 32, 32, 768)  0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 32, 32, 768)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 768)  0           average_pooling2d_12[0][0]
#                                                                  average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 32, 32, 768)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 768)  5309184     re_lu_40[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 32, 32, 768)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 768)  590592      add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 768)  5309184     re_lu_41[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 16, 16, 768)  0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 16, 16, 768)  0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 768)  0           average_pooling2d_14[0][0]
#                                                                  average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# self_attention_3 (SelfAttention (None, 16, 16, 768)  738624      add_19[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 16, 16, 768)  0           self_attention_3[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 16, 16, 1536) 10618368    re_lu_42[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 16, 16, 1536) 0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 16, 16, 1536) 1181184     self_attention_3[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 16, 16, 1536) 21235200    re_lu_43[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 8, 8, 1536)   0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 8, 8, 1536)   0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 1536)   0           average_pooling2d_16[0][0]
#                                                                  average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 8, 8, 1536)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 8, 8, 1536)   21235200    re_lu_44[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 8, 8, 1536)   0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 1536)   2360832     add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 8, 8, 1536)   21235200    re_lu_45[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18 (AveragePo (None, 4, 4, 1536)   0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_19 (AveragePo (None, 4, 4, 1536)   0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, 4, 1536)   0           average_pooling2d_18[0][0]
#                                                                  average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 4, 4, 1536)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 4, 4, 1536)   21235200    re_lu_46[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 4, 4, 1536)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# class (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 4, 4, 1536)   2360832     add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 4, 4, 1536)   21235200    re_lu_47[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 128)       2688        class[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 4, 4, 1536)   0           conv2d_70[0][0]
#                                                                  conv2d_72[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 128)          0           embedding_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1536)         0           add_22[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 1664)         0           flatten_3[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1665        concatenate_14[0][0]
# ==================================================================================================
# Total params: 145,493,889
# Trainable params: 145,493,889
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, g_loss_fn, d_loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.g_loss_fn = g_loss_fn
        self.d_loss_fn = d_loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, data_batch):
        real_images,anno=data_batch
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        fake_anno=tf.cast(tf.random.uniform(shape=[batch_size,1]) * class_types, tf.int32)

        with tf.GradientTape() as d_tape, tf.GradientTape() as g_tape:
            generated_images = self.generator({'noise':random_latent_vectors, 'class':fake_anno})
            gen_predictions = self.discriminator({'image':generated_images,'class':fake_anno})
            real_predictions = self.discriminator({'image':real_images,'class':anno})
            d_loss = self.d_loss_fn(real_predictions, gen_predictions)
            g_loss = self.g_loss_fn(gen_predictions)

        d_grads = d_tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(d_grads, self.discriminator.trainable_weights)
        )

        g_grads = g_tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(g_grads, self.generator.trainable_weights))
        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=100, noise=None, anno=None):
        self.num_img = num_img
        self.latent_dim = latent_dim
        if noise==None:
          self.random_latent_vectors = random_latent_vectors = tf.random.normal(shape=(num_img, latent_dim))
        else:
          self.random_latent_vectors=noise
        
        if anno==None:
          self.fake_anno=fake_anno=tf.cast(np.tile(np.arange(10),10),tf.int32)
        else:
          self.fake_anno=anno
    def on_epoch_end(self, epoch, logs=None):
        generated_images = self.model.generator({'noise':self.random_latent_vectors,'class':self.fake_anno})
        generated_images = generated_images*127.5+127.5
        generated_images.numpy()

        fig=plt.figure(figsize=(20,20))
        for i in range(self.num_img):
            plt.subplot(10,10,i + 1)
            img = keras.preprocessing.image.array_to_img(generated_images[i])
            plt.imshow(img)
            plt.axis('off')
        plt.savefig(f'generated_image_EPOCH_{epoch}.png')

# %%
num_img=100
random_latent_vectors = tf.random.normal(shape=(num_img, latent_dim))
fake_anno=tf.cast(np.tile(np.arange(10),10),tf.int32)

# %%
def hinge_loss_d(true_pred, fake_pred):
  real_loss=tf.math.minimum(tf.zeros_like(true_pred), -1 + true_pred)
  fake_loss=tf.math.minimum(tf.zeros_like(fake_pred), -1 - fake_pred)
  return real_loss + fake_loss
def hinge_loss_g(fake_pred):
  return fake_pred

bce=tf.keras.losses.BinaryCrossentropy(from_logits=True)
def generator_ce(fake_output):
  return bce(tf.zeros_like(fake_output),fake_output)
def discriminator_ce(real_output, fake_output):
  real_loss = bce(tf.zeros_like(real_output), real_output)
  fake_loss = bce(tf.ones_like(fake_output), fake_output)
  total_loss = real_loss + fake_loss
  return total_loss

# %%
gen_images=generator({'noise':random_latent_vectors,'class':fake_anno})
fig=plt.figure(figsize=(20,20))
for i in range(100):
    plt.subplot(10,10,i + 1)
    img = keras.preprocessing.image.array_to_img(gen_images[i])
    plt.imshow(img)
    plt.axis('off')
plt.show()
print(discriminator({'image':gen_images,'class':fake_anno}).numpy())
# Out:
# [[-0.01571147]
#  [ 0.01344703]
#  [ 0.0761314 ]
#  [-0.01313256]
#  [ 0.2042903 ]
#  [ 0.08750517]
#  [ 0.017924  ]
#  [-0.05041586]
#  [ 0.12589747]
#  [ 0.05181412]
#  [ 0.18967572]
#  [-0.02754579]
#  [-0.0730904 ]
#  [ 0.11298141]
#  [-0.04368241]
#  [ 0.07455709]
#  [-0.06177478]
#  [-0.02649902]
#  [ 0.16303037]
#  [ 0.06075202]
#  [-0.02371351]
#  [-0.04286614]
#  [-0.00088166]
#  [-0.00734782]
#  [-0.06197222]
#  [-0.01606038]
#  [-0.0530881 ]
#  [ 0.12103166]
#  [ 0.10993401]
#  [-0.03572947]
#  [-0.04424243]
#  [-0.03393559]
#  [-0.01716566]
#  [ 0.12744144]
#  [ 0.01005945]
#  [ 0.0169968 ]
#  [-0.02126409]
#  [ 0.06943119]
#  [-0.01125693]
#  [-0.01634939]
#  [ 0.14327481]
#  [-0.07847664]
#  [-0.03884019]
#  [ 0.00910023]
#  [ 0.04478015]
#  [ 0.05495945]
#  [-0.06804255]
#  [ 0.04987805]
#  [ 0.08662003]
#  [ 0.20326704]
#  [-0.03026754]
#  [ 0.10864978]
#  [-0.03014468]
#  [ 0.05755178]
#  [-0.08826852]
#  [ 0.0493248 ]
#  [-0.04019865]
#  [-0.011452  ]
#  [-0.00153451]
#  [ 0.08284444]
#  [-0.02237475]
#  [ 0.1361994 ]
#  [ 0.05950704]
#  [ 0.04733745]
#  [-0.02945103]
#  [-0.01966507]
#  [-0.03910078]
#  [ 0.06462057]
#  [ 0.01187342]
#  [-0.02059379]
#  [-0.00820782]
#  [ 0.011687  ]
#  [-0.04479718]
#  [-0.0529619 ]
#  [-0.0448504 ]
#  [-0.03666012]
#  [ 0.00900958]
#  [ 0.10068779]
#  [ 0.01679881]
#  [-0.0605997 ]
#  [ 0.04333755]
#  [ 0.05629011]
#  [-0.01342256]
#  [ 0.06314648]
#  [-0.04597158]
#  [-0.01770207]
#  [ 0.02359582]
#  [-0.00339457]
#  [ 0.08995172]
#  [ 0.00654632]
#  [ 0.00426551]
#  [ 0.16446142]
#  [-0.04682489]
#  [ 0.0601102 ]
#  [-0.057869  ]
#  [-0.06112909]
#  [-0.03455633]
#  [-0.02193152]
#  [ 0.15288645]
#  [ 0.05555508]]

# %%
epochs = 100  # In practice, use ~100 epochs

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    d_loss_fn=hinge_loss_d,
    g_loss_fn=hinge_loss_g,
)

gan.fit(train_dataset.batch(128), epochs=epochs, callbacks=[GANMonitor(num_img=num_img, latent_dim=latent_dim, noise=random_latent_vectors, anno=fake_anno)])
# Out:
# Epoch 1/100
